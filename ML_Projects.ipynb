# %% [markdown]
# # **Machine Learning Projects** #
# I am going to discuss Two projects as the part of this project.
# 1. Student grade prediction
# 2. Employee salary prediction
#
# As we can see the output label in these two senarios is continuous so regression will be used

# %% [markdown]
# ## **Student grade Prediction** ##
#
# The objective of this project is to predict the grades of the students based on some features

# %% [markdown]
# ### **Data Collection** ###
# Dataset Link : https://www.kaggle.com/datasets/uciml/student-alcohol-consumption

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/student-mat.csv")
print(df.shape)
df.head()
# Out:
# (395, 33)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### **Exploratory Data Analysis** ###
#
# **About the Dataset**
#
# The dataset contains the information about the students of two schools GP and MS.<br>
# **Features** <br>
# 1.  school : binary GP or MS
# 2.  sex : binary F or M
# 3.  age : numeric
# 4.  .
# 5.  .
# 32. G2 : grade numeric
# ---
# **output** <br>
# 33.  G3: grade numeric
#
#
#
#
#
# summary statistics

# %%
df['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %% [markdown]
# **Data Visualization**

# %%
plt.figure(figsize=(10, 6))
b = sns.countplot(data=df, x='G3', palette='viridis')
b.axes.set_title("Distribution of Final Grades", fontsize=30)
b.set_xlabel("Final Grade",fontsize=10)
b.set_ylabel("Count",fontsize=10)
plt.show()
# Out:
# <ipython-input-6-0977dfda9705>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.countplot(data=df, x='G3', palette='viridis')

# %% [markdown]
# ### **Data Preprocessing** ###

# %% [markdown]
# #### **a)Find Null values** ####
# No null values

# %%
df.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# #### **b)Remove unnecessary features** ####

# %%
df.drop(["school", "age","address"],axis=1,inplace=True)
df.head()
# Out:
#   sex famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  \
# 0   F     GT3       A     4     4  at_home   teacher  course   mother
# 1   F     GT3       T     1     1  at_home     other  course   father
# 2   F     LE3       T     1     1  at_home     other   other   mother
# 3   F     GT3       T     4     2   health  services    home   mother
# 4   F     GT3       T     3     3    other     other    home   father
#
#    traveltime  ...  famrel  freetime goout Dalc Walc health absences  G1  G2  \
# 0           2  ...       4         3     4    1    1      3        6   5   6
# 1           1  ...       5         3     3    1    1      3        4   5   5
# 2           1  ...       4         3     2    2    3      3       10   7   8
# 3           1  ...       3         2     2    1    1      5        2  15  14
# 4           1  ...       4         3     2    1    2      5        4   6  10
#
#    G3
# 0   6
# 1   6
# 2  10
# 3  15
# 4  10
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['sex', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason',
#        'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health',
#        'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# #### **c)Mapping** ####

# %%
d = { 'yes':1,'no':0 }
df['schoolsup'] = df['schoolsup'].map(d)
df['famsup'] = df['famsup'].map(d)
df['paid'] = df['paid'].map(d)
df['activities'] = df['activities'].map(d)
df['nursery'] = df['nursery'].map(d)
df['higher'] = df['higher'].map(d)
df['internet'] = df['internet'].map(d)
df['romantic'] = df['romantic'].map(d)

# %%
d = {'F':1,'M':0}
df['sex'] = df['sex'].map(d)

d = {'home':0, 'reputation':1, 'course':2, 'other':3}
df['reason'] = df['reason'].map(d)

d = {'mother':0 , 'father':1 , 'other': 2}
df['guardian'] = df['guardian'].map(d)

d = {'LE3':0, 'GT3':1}
df['famsize'] = df['famsize'].map(d)

d = {'A':0, 'T':1}
df['Pstatus'] = df['Pstatus'].map(d)

d = {'at_home':0,'health':1,'services':2,'teacher':3,'other':4}
df['Mjob'] = df['Mjob'].map(d)
df['Fjob'] = df['Fjob'].map(d)

df.head()
# Out:
#    sex  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  guardian  \
# 0    1        1        0     4     4     0     3       2         0
# 1    1        1        1     1     1     0     4       2         1
# 2    1        0        1     1     1     0     4       3         0
# 3    1        1        1     4     2     1     2       0         0
# 4    1        1        1     3     3     4     4       0         1
#
#    traveltime  ...  famrel  freetime  goout  Dalc  Walc  health  absences  G1  \
# 0           2  ...       4         3      4     1     1       3         6   5
# 1           1  ...       5         3      3     1     1       3         4   5
# 2           1  ...       4         3      2     2     3       3        10   7
# 3           1  ...       3         2      2     1     1       5         2  15
# 4           1  ...       4         3      2     1     2       5         4   6
#
#    G2  G3
# 0   6   6
# 1   5   6
# 2   8  10
# 3  14  15
# 4  10  10
#
# [5 rows x 30 columns]

# %% [markdown]
# #### **d)Feature Extraction** ####

# %%
x = df.drop("G3",axis=1)
y = df['G3']

# %% [markdown]
# #### **e)Train-test split** ####

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3,random_state=21)
train_x.head()
# Out:
#      sex  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  guardian  \
# 44     1        0        1     2     2     4     0       2         1
# 143    1        0        1     1     1     0     0       2         0
# 53     1        1        1     4     4     2     2       2         0
# 102    0        1        1     4     4     2     4       2         0
# 388    1        0        1     3     1     3     2       2         0
#
#      traveltime  ...  romantic  famrel  freetime  goout  Dalc  Walc  health  \
# 44            2  ...         0       4         3      3     2     2       5
# 143           1  ...         0       3         4      4     3     3       1
# 53            1  ...         0       3         3      4     2     3       5
# 102           1  ...         0       5         3      3     1     1       5
# 388           1  ...         0       4         3      4     1     1       1
#
#      absences  G1  G2
# 44         14  10  10
# 143         2  14  14
# 53          0   8  10
# 102         4  10  13
# 388         0   7   9
#
# [5 rows x 29 columns]

# %% [markdown]
# ### **Model Implementation** ###

# %% [markdown]
# #### **Training** ####

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %% [markdown]
# #### **Prediction** ####

# %%
predict_y = model.predict(test_x)
print(predict_y)
# Out:
# [ 7.74214342 18.37266112  8.92150802 13.4177207   8.9003699  10.56509707
#   4.4240763  14.43912818 16.4089491  -1.16659731  8.47633279 14.12380432
#  15.11732597 10.70291169  9.8216325  13.05412256 13.24601121 18.62946213
#   9.25935901 11.01903696 10.1328274   8.88346267 20.05812845 -0.67620434
#  10.5436534   6.66539167  8.42702177 18.84441715 10.06128977 15.3919394
#  14.52052473 13.71106136  6.56692076 14.99112532  4.73829376  5.95728608
#   8.04339294  9.20121561 10.89142956 11.52545086 11.63093363  7.83744016
#   7.64418011  8.17761188  6.96866881 14.8129274   4.18652514  9.18078438
#  14.35931271 15.63672913 14.96524198  9.00259239  6.12128274  5.91216385
#   5.10221517 11.39322932  9.97462506  6.93345702 18.37326306  8.7252571
#  -0.18874852  6.70413096 15.27221145  5.15991833 15.51925057  5.75507841
#   7.24440008 10.12740661 12.99618612  8.72475171 18.92752578  9.03723636
#  10.82201539 10.61022329  8.38178387  3.5451002  10.56688463  8.48455867
#  -1.47574724 12.79031479  8.18908988 14.59235299 11.73675111 13.63956979
#  10.95899307 12.52355398 13.1058584  11.95441484  8.5831535  10.35132589
#   8.96053368  5.43305503 11.43548055 14.05584945  9.01694603 13.30924739
#   6.95124408 17.50089783  8.80380957 11.10227813 11.70983845  9.57825001
#  12.19420768 10.19767566  6.78562586  8.7024218   9.16165224  0.28389596
#  13.74527316  4.37717324 10.05504587 15.75073205 12.60545382  3.67672486
#   7.68843985 11.42060541 14.37400879  7.4775846   9.5894991 ]

# %% [markdown]
# #### **Evaluation** ####

# %%
test_accuracy = model.score(test_x,test_y)
train_accuracy = model.score(train_x,train_y)
print("Train accuracy = ",train_accuracy,"test accuracy = ",test_accuracy)
# Out:
# Train accuracy =  0.8468212801071648 test accuracy =  0.8144750277155215

# %% [markdown]
# ### **Detect and Remove outliers** ###

# %%
# Create a boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='G3', data=df, orient='v', width=0.5, color='lightblue')

# Add data points with stripplot
sns.stripplot(x='G3', data=df, jitter=True, alpha=0.5, color='blue')

plt.title('Box Plot with Data Points')
plt.xlabel('Grades')
plt.grid(True)
plt.show()

df['G3'].quantile(0.25)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# 8.0

# %%
q1 = df['G3'].quantile(0.25)
q3 = df['G3'].quantile(0.75)

iqr = q3-q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

df = df[(df['G3'] > lower_bound) & (df['G3'] < upper_bound)]
df
# Out:
#      sex  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  guardian  \
# 0      1        1        0     4     4     0     3       2         0
# 1      1        1        1     1     1     0     4       2         1
# 2      1        0        1     1     1     0     4       3         0
# 3      1        1        1     4     2     1     2       0         0
# 4      1        1        1     3     3     4     4       0         1
# ..   ...      ...      ...   ...   ...   ...   ...     ...       ...
# 390    0        0        0     2     2     2     2       2         2
# 391    0        0        1     3     1     2     2       2         0
# 392    0        1        1     1     1     4     4       2         2
# 393    0        0        1     3     2     2     4       2         0
# 394    0        0        1     1     1     4     0       2         1
#
#      traveltime  ...  famrel  freetime  goout  Dalc  Walc  health  absences  \
# 0             2  ...       4         3      4     1     1       3         6
# 1             1  ...       5         3      3     1     1       3         4
# 2             1  ...       4         3      2     2     3       3        10
# 3             1  ...       3         2      2     1     1       5         2
# 4             1  ...       4         3      2     1     2       5         4
# ..          ...  ...     ...       ...    ...   ...   ...     ...       ...
# 390           1  ...       5         5      4     4     5       4        11
# 391           2  ...       2         4      5     3     4       2         3
# 392           1  ...       5         5      3     3     3       3         3
# 393           3  ...       4         4      1     3     4       5         0
# 394           1  ...       3         2      3     3     3       5         5
#
#      G1  G2  G3
# 0     5   6   6
# 1     5   5   6
# 2     7   8  10
# 3    15  14  15
# 4     6  10  10
# ..   ..  ..  ..
# 390   9   9   9
# 391  14  16  16
# 392  10   8   7
# 393  11  12  10
# 394   8   9   9
#
# [395 rows x 30 columns]

# %% [markdown]
# ### **Retrain the Model** ####

# %%
x = df.drop("G3",axis=1)
y = df['G3']
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3,random_state=21)
model = LinearRegression()
model.fit(train_x,train_y)
test_accuracy = model.score(test_x,test_y)
train_accuracy = model.score(train_x,train_y)
print("Train accuracy = ",train_accuracy,"test accuracy = ",test_accuracy)
# Out:
# Train accuracy =  0.8468212801071648 test accuracy =  0.8144750277155215

# %% [markdown]
# ## **Employee Salary Predition** ##
#
# The objective of this project is to predict the grades of the students based on some features

# %% [markdown]
# ### **Data Collection** ###

# %%
df2 = pd.read_csv("/salary_data.csv")
df2.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# ### **Exploratory Data Analysis** ###

# %%
df2.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df2.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# ### **Data Preprocessing** ###

# %% [markdown]
# #### **1.Find Null vakues** ####

# %%
df2.isnull().any()
# Out:
# YearsExperience    False
# Salary             False
# dtype: bool

# %%
df2.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# #### **2.Feature Extraction** ####

# %%
x = df2['YearsExperience']
y = df2['Salary']

# %% [markdown]
# #### **3.Data visualization** ####

# %%
plt.plot(x,y)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x,y,s=y/1000)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Salary', data=df2, orient='v', width=0.5, color='lightblue')

sns.stripplot(x='Salary', data=df2, jitter=True, alpha=0.5, color='blue')

plt.title('Box Plot with Data Points')
plt.xlabel('Salary')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# #### **4.Outlier Detection** ####

# %%
q1 = y.quantile(0.25)
q3 = y.quantile(0.75)
iqr = q3 - q1
lower_bound = q1-1.5*iqr
upper_bound = q3+1.5*iqr

df2 = df2[(df2['Salary']>lower_bound) & (df2['Salary']<upper_bound)]
df2.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# #### **5.Train-test split** ####

# %%
x = df2[['YearsExperience']]
y = df2['Salary']

train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3, random_state=21)

# %% [markdown]
# ### **Model Implementation** ###

# %% [markdown]
# #### **Creation and Training** ####

# %%
model2 = LinearRegression()
model2.fit(train_x,train_y)

predictions = model2.predict(test_x)
predictions
# Out:
# array([ 51683.73508963, 101539.89662592,  98717.84974651, 121294.22478181,
#         36632.81839943,  91192.39140141,  80844.88617689,  54505.78196904,
#        114709.44872984])

# %% [markdown]
# #### **Evaluation** ####

# %%
test_accuracy = model2.score(test_x,test_y)
train_accuracy = model2.score(train_x,train_y)
print("Train accuracy = ",train_accuracy,"test accuracy = ",test_accuracy)
# Out:
# Train accuracy =  0.9604266612005813 test accuracy =  0.9244145228524281

# %% [markdown]
# ### **conclusion** ###
# since the Years of experience and Salary are linearly related ,the Linear Regression model has given high accuracy which is 0.96
